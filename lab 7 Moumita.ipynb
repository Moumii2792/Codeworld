# %% [markdown]
# # Futures Contract Excercise

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %%
import math

# A python function that calculates the value of a futures contract

def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 100;         
benefit         = 0;        
miscCharges     = 1;
t               = 25;      
r               = 0.05;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:100.00
# Expected benefits like dividend:0.00
# Expected costs to be incurred:1.00
# Time to expiry of the futures contract in days:25
# Interest Rate in percent:5.00
# Price of the futures contract:342.02

# %% [markdown]
# ## Lab Q1)
#
# Scenarios
#
# 1. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 1%
# 2. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 5%
# 3. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 8%
# 4. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 4%
# 5. Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 10%
#
# a) Calculate futures prices based on the above conditions
#
# b) Change the time value from 10 years to the following & calculate futures prices. 1:9yrs,2:8yrs,3:7yrs,4:6yrs,5:5yrs
#
# c) Same process as b) but with changed dividends. 1:50,2:40,3:30,4:20,5:5
#
# d) What can you observe from modifying these parameters in futures prices calcualtion? Think back to our lessons from TVM and the relationship between the parameters to the futures prices (no more than 1 paragraph).

# %% [markdown]
# # Scenario 1
# Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 1%

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 10;      
r               = 0.01;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:10
# Interest Rate in percent:1.00
# Price of the futures contract:176.74

# %% [markdown]
# # Scenario 2
# Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 5%

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 10;      
r               = 0.05;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:10
# Interest Rate in percent:5.00
# Price of the futures contract:260.62

# %% [markdown]
# # Scenario 3
# Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 8%

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 10;      
r               = 0.08;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:10
# Interest Rate in percent:8.00
# Price of the futures contract:345.43

# %% [markdown]
# # Scenario 4
# Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 4%

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 10;      
r               = 0.04;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:10
# Interest Rate in percent:4.00
# Price of the futures contract:236.84

# %% [markdown]
# # Scenario 5
# Spot Price: 150, Dividend:10, costs:20, time:10 years, risk free rate: 10%

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 10;      
r               = 0.10;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:10
# Interest Rate in percent:10.00
# Price of the futures contract:415.00

# %% [markdown]
# # b) Change the time value from 10 years to the following & calculate futures prices. 1:9yrs,2:8yrs,3:7yrs,4:6yrs,5:5yrs

# %% [markdown]
# # with 9 years

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 9;      
r               = 0.01;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:9
# Interest Rate in percent:1.00
# Price of the futures contract:174.99

# %% [markdown]
# # with 8 years

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 8;      
r               = 0.05;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:8
# Interest Rate in percent:5.00
# Price of the futures contract:236.39

# %% [markdown]
# # with 7 years

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 7;      
r               = 0.08;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:7
# Interest Rate in percent:8.00
# Price of the futures contract:274.21

# %% [markdown]
# # with 6 years

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 6;      
r               = 0.04;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:6
# Interest Rate in percent:4.00
# Price of the futures contract:202.45

# %% [markdown]
# # with 5 years

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =10;        
miscCharges     = 20;
t               = 5;      
r               = 0.10;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:10.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:5
# Interest Rate in percent:10.00
# Price of the futures contract:257.68

# %% [markdown]
# # c) Same process as b) but with changed dividends. 1:50,2:40,3:30,4:20,5:5

# %% [markdown]
# # with t = 9 years , dividand = 50$

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =50;        
miscCharges     = 20;
t               = 9;      
r               = 0.01;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:50.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:9
# Interest Rate in percent:1.00
# Price of the futures contract:131.24

# %% [markdown]
# # with t = 8 years , dividand = 40$

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =40;        
miscCharges     = 20;
t               = 8;      
r               = 0.05;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:40.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:8
# Interest Rate in percent:5.00
# Price of the futures contract:192.07

# %% [markdown]
# # with t = 7 years, dividand = 30$

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =30;        
miscCharges     = 20;
t               = 7;      
r               = 0.08;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:30.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:7
# Interest Rate in percent:8.00
# Price of the futures contract:239.94

# %% [markdown]
# # with t = 6 years , dividand = 20$

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =20;        
miscCharges     = 20;
t               = 6;      
r               = 0.04;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:20.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:6
# Interest Rate in percent:4.00
# Price of the futures contract:189.80

# %% [markdown]
# # with t = 5 years , dividand = 5$

# %%
def FuturePrice(spotPrice, benefit, cost, r, t):
    return (spotPrice - benefit + cost)*math.pow(1 + r, t);

spotPrice       = 150;         
benefit         =5;        
miscCharges     = 20;
t               = 5;      
r               = 0.10;
ratePerday      = r/365;

contractPrice   = FuturePrice(spotPrice, benefit, miscCharges, r, t);

print("Spot price of the equity futures contract:%3.2f"%spotPrice);
print("Expected benefits like dividend:%3.2f"%benefit);
print("Expected costs to be incurred:%3.2f"%miscCharges);
print("Time to expiry of the futures contract in days:%d"%t);
print("Interest Rate in percent:%2.2f"%(r*100));
print("Price of the futures contract:%3.2f"%contractPrice)
# Out:
# Spot price of the equity futures contract:150.00
# Expected benefits like dividend:5.00
# Expected costs to be incurred:20.00
# Time to expiry of the futures contract in days:5
# Interest Rate in percent:10.00
# Price of the futures contract:265.73

# %% [markdown]
# # d) What can you observe from modifying these parameters in futures prices calcualtion? Think back to our lessons from TVM and the relationship between the parameters to the futures prices (no more than 1 paragraph).
#
# The time value of money revolves around the concept that having money now is more valuable than the identical sum of it in the future due to its potential earning capacity. While figuring the future estimation of moeny secured up a venture, you should have an approach to consider both the potential compund ineterest you could get by holding the speculation and the danger inflation or failed marketing conditions.
# By modifying the parameters it is observed that the future price is often changed slightly depending on the parameters it is calculated on. Any rise in dividend lowers the future price. Also, with the incerasse in years the future price is decreasing. One should also keep in mind that the future value not only depends on the ineterest rate and time, but also how many times it has been compounded each year.

# %% [markdown]
# ## Lab Q2)
#
# Research into the topic of Credit Default Swap. This played a major role in ushering the would into the Great Recession of 2008. Please prepare a summary (no more than 2 paragraphs, single spaced) outlining its definiton and the role it played in 2008.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Lab Q3)
#
# Based on what's been happening in the market (looking back past two to three weeks), put together a short thought summary in terms of the appropriate portfolio strategy(1) that can be employed given the market condition. Pick 4-6 companies (stocks) that you will use to put together a portfolio based on the chosen strategy (1 page max, single space).

# %% [markdown]
# # Sortino analysis

# %%
startdate = datetime.datetime(2020, 7,1 )
enddate = datetime.datetime(2020, 7, 21)
Nflx=web.get_data_yahoo("Nflx",startdate, enddate,)
FB=web.get_data_yahoo("FB",startdate, enddate)
WMT=web.get_data_yahoo("WMT",startdate, enddate)
AMZN=web.get_data_yahoo("AMZN",startdate, enddate)

# %%
Nflx.rename(columns={'Adj Close': 'Nflx_Adj Close'}, inplace=True)
Nflx.rename(columns={'Open': 'Nflx_Open'}, inplace=True)
FB.rename(columns={'Adj Close': 'FB_Adj Close'}, inplace=True)
FB.rename(columns={'Open': 'FB_Open'}, inplace=True)
WMT.rename(columns={'Adj Close': 'WMT_Adj Close'}, inplace=True)
WMT.rename(columns={'Open': 'WMT_Open'}, inplace=True)
AMZN.rename(columns={'Adj Close': 'AMZN_Adj Close'}, inplace=True)
AMZN.rename(columns={'Open': 'AMZN_Open'}, inplace=True)

# %%
join1=Nflx.join(FB[['FB_Open','FB_Adj Close']])
join2=join1.join(WMT[['WMT_Open','WMT_Adj Close']])
Sortino=join2.join(AMZN[['AMZN_Open','AMZN_Adj Close']])
Sortino.drop(['High','Low','Close','Volume'],axis=1,inplace=True)
Sortino

# %%
Sortino.to_excel("Sortino_analysis.xlsx",
             sheet_name='Stock_return',index=True)

# %% [markdown]
# # Whats happening in the market?
#
# Depending on the past two weeks daily prices. The stock prices of Amazon have been increased by 42.86. If we look at the past two weeks daily prices and the return, then we can understand that Amazon is doing well in the present market conditions.
# If we look at the returns also, then amazon is giving a higher return compared to any other companies. the reason that amazon is doing so well in the current situation could be the effect of COVID 19 as people are avoiding social contact and using online services more for every other needs. This is a generalized perception that everybody can have in the present situation.
#
# Any kind of investments always comes with a concern of risk. Due to the present situation where the risk pertaining to any stocks is unpredictable, it is better to perform sortino analysis to understand as it differentiates the harmful volatility from the over all by measuring the risk adjusted return of a portfolio. This strategy is used by various investors to know the expected return and given the market condition; this is the primary concern any investor might think about before investing.
#
# The sortino analysis provides a better view of the risk adjusted rate of portfolio as it uses only the downward deviation as its risk factor, as the upward risk is never a factor for analysts.
#
# When the market situation is risky where most pf the companies are not doing very well, it is important to select a better portfolio in terms of risk as well as return. Sortino analysis is used to evaluate the return in any investment with a provided level of downside risk, therefore this is more useful for financial decision making in the present market situation.
# Sortino analysis is very important tool used for choosing a best portfolio because it takes into consideration the bad risks, which is more useful.
#
# Depending on the analysis done, it is recommended to chooses amazon as its ratio is in positive (0.09) unlike the rest of the three stocks. It means that investing on amazon can be profitable and employed with lower risks.
