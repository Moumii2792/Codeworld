# %% [markdown]
# # Lab-5 Moumita

# %%
import pandas as pd  
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas_datareader.data as web
import scipy.optimize as sco
plt.style.use('fivethirtyeight')
np.random.seed(777)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# # Stocks:
# Dis--------Disney
#
# FB--------Facebook
#
# NFLX-------Netflix
#
# SBUX------Starbucks
#
# WMT-------Walmart

# %% [markdown]
# # Pick 5 companies to download the stock data from 01/01/2020 to 06/30/2020 and put them in a dataframe

# %%
stocks = ['DIS','FB','NFLX','SBUX','WMT']

# %%
#download daily price data for each of the stocks in the portfolio
Daily_price = web.DataReader(stocks,data_source='yahoo',start='01/01/2020',end='06/30/2020')['Adj Close']
Daily_price
# Out:
# Symbols            DIS          FB        NFLX       SBUX         WMT
# Date
# 2020-01-02  148.199997  209.779999  329.809998  88.435722  117.897430
# 2020-01-03  146.500000  208.669998  325.899994  87.921051  116.856636
# 2020-01-06  145.649994  212.600006  335.829987  87.228210  116.618736
# 2020-01-07  145.699997  213.059998  330.750000  86.960976  115.538292
# 2020-01-08  145.399994  215.220001  339.260010  87.970535  115.141792
# ...                ...         ...         ...        ...         ...
# 2020-06-24  112.070000  234.020004  457.850006  73.639999  120.300003
# 2020-06-25  111.360001  235.679993  465.910004  73.849998  119.709999
# 2020-06-26  109.099998  216.080002  443.399994  71.570000  118.320000
# 2020-06-29  111.519997  220.639999  447.239990  73.480003  119.059998
# 2020-06-30  111.510002  227.070007  455.040009  73.589996  119.779999
#
# [125 rows x 5 columns]

# %%
 Daily_price.head()
# Out:
# Symbols            DIS          FB        NFLX       SBUX         WMT
# Date
# 2020-01-02  148.199997  209.779999  329.809998  88.435722  117.897430
# 2020-01-03  146.500000  208.669998  325.899994  87.921051  116.856636
# 2020-01-06  145.649994  212.600006  335.829987  87.228210  116.618736
# 2020-01-07  145.699997  213.059998  330.750000  86.960976  115.538292
# 2020-01-08  145.399994  215.220001  339.260010  87.970535  115.141792

# %%
 Daily_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 125 entries, 2020-01-02 to 2020-06-30
# Data columns (total 5 columns):
# DIS     125 non-null float64
# FB      125 non-null float64
# NFLX    125 non-null float64
# SBUX    125 non-null float64
# WMT     125 non-null float64
# dtypes: float64(5)
# memory usage: 5.9 KB

# %% [markdown]
# # a)	Plot a pricing chart for the duration of the timeline of all five stocks

# %%
plt.figure(figsize=(15, 6))
for c in  Daily_price.columns.values:
    plt.plot( Daily_price.index,  Daily_price[c], lw=3, alpha=0.8,label=c)
plt.legend(loc='upper left', fontsize=14)
plt.ylabel('price in $')
# Out:
# C:\Users\moumi\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'price in $')

# %% [markdown]
# # Explanation:
# The grahs is plotted by using matplolob package.
# Plotting is done after looping the vlaue of the column of the table. In the graph the x axis is the index or date and the y axis is the vlaue in the columns or price. Therefore tha graph is plotted against year and price of the stocks. The label for x axis is value in the date column. Lw is the line width in the graph. The legend are the defaulted best in the upper left corner with font size 14. The label for y axis is "price in $".
# The over all figure size is 15,6, which describes the size of the graph.

# %% [markdown]
# # b)	Calculate daily returns of each stock and plot them in a chart.

# %%
returns = Daily_price.pct_change()
plt.figure(figsize=(15, 6))
for c in returns.columns.values:
    plt.plot(returns.index, returns[c], lw=3, alpha=0.8,label=c)
plt.legend(loc='upper right', fontsize=14)
plt.ylabel('daily returns')
# Out:
# Text(0, 0.5, 'daily returns')

# %% [markdown]
# # Explanation:
# In the above line of code. "pct_change()" is used to calculate the change i.e. between new vlaue form the old value.
# The grahs is plotted by using matplolob package. Plotting is done after looping the value of the column of the table. In the graph the x axis is the index or date and the y axis is the vlaue in the columns or price of the return data. Therefore tha graph is plotted against year and daily returns of the stocks. The label for x axis is value in the date column. Lw is the line width in the graph. The legend are the defaulted best in the upper right corner with font size 14. The label for y axis is "daily returns"
# The over all figure size is 15,6, which describes the size of the graph.
